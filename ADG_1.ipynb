# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

df= pd.read_csv('/Users/mananbhatt/Downloads/archive-3/covid19_in.csv')
state_df= pd.read_csv('/Users/mananbhatt/Downloads/archive-3/covid19_in_statewise_aggregated.csv')

df
# Out:
#       patientId  reportedOn  onsetEstimate ageEstimate gender  \
# 0             1  30/01/2020            NaN          20      F
# 1             2  02/02/2020            NaN         NaN    NaN
# 2             3  03/02/2020            NaN         NaN    NaN
# 3             4  02/03/2020            NaN          45      M
# 4             5  02/03/2020            NaN          24      M
# ...         ...         ...            ...         ...    ...
# 5394       5395         NaN            NaN         NaN    NaN
# 5395       5396         NaN            NaN         NaN    NaN
# 5396       5397         NaN            NaN         NaN    NaN
# 5397       5398         NaN            NaN         NaN    NaN
# 5398       5399         NaN            NaN         NaN    NaN
#
#                           city    district      state     status  \
# 0                     Thrissur    Thrissur     Kerala  Recovered
# 1                    Alappuzha   Alappuzha     Kerala  Recovered
# ...

# %%
state_df
# Out:
#                             state        date  cases_count
# 0     Andaman and Nicobar Islands  2020-01-30            0
# 1     Andaman and Nicobar Islands  2020-01-31            0
# 2     Andaman and Nicobar Islands  2020-02-01            0
# 3     Andaman and Nicobar Islands  2020-02-02            0
# 4     Andaman and Nicobar Islands  2020-02-03            0
# ...                           ...         ...          ...
# 2203                  West Bengal  2020-04-03           53
# 2204                  West Bengal  2020-04-04           53
# 2205                  West Bengal  2020-04-05           80
# 2206                  West Bengal  2020-04-06           80
# 2207                  West Bengal  2020-04-07           91
#
# [2208 rows x 3 columns]

# %%
df.dropna(subset=['state'],axis=0,inplace=True)

# %%
df
# Out:
#       patientId  reportedOn  onsetEstimate ageEstimate gender  \
# 0             1  30/01/2020            NaN          20      F
# 1             2  02/02/2020            NaN         NaN    NaN
# 2             3  03/02/2020            NaN         NaN    NaN
# 3             4  02/03/2020            NaN          45      M
# 4             5  02/03/2020            NaN          24      M
# ...         ...         ...            ...         ...    ...
# 5094       5095  07/04/2020            NaN          27      M
# 5095       5096  07/04/2020            NaN          67      F
# 5096       5097  07/04/2020            NaN          40      M
# 5097       5098  07/04/2020            NaN          42      F
# 5098       5099  07/04/2020            NaN          40      M
#
#                           city    district      state        status  \
# 0                     Thrissur    Thrissur     Kerala     Recovered
# 1                    Alappuzha   Alappuzha     Kerala     Recovered
# ...

# %%
df.contractedFrom.first_valid_index()
# Out:
# 6

# %%
df.contractedFrom[6]
# Out:
# 'P6'

# %%
df.dropna(subset=['ageEstimate'], axis=0, inplace=True)

# %%
df
# Out:
#       patientId  reportedOn  onsetEstimate ageEstimate gender  \
# 0             1  30/01/2020            NaN          20      F
# 3             4  02/03/2020            NaN          45      M
# 4             5  02/03/2020            NaN          24      M
# 5             6  03/03/2020            NaN          69      M
# 6             7  04/03/2020            NaN          55    NaN
# ...         ...         ...            ...         ...    ...
# 5094       5095  07/04/2020            NaN          27      M
# 5095       5096  07/04/2020            NaN          67      F
# 5096       5097  07/04/2020            NaN          40      M
# 5097       5098  07/04/2020            NaN          42      F
# 5098       5099  07/04/2020            NaN          40      M
#
#                           city    district      state        status  \
# 0                     Thrissur    Thrissur     Kerala     Recovered
# 3     East Delhi (Mayur Vihar)  East Delhi      Delhi     Recovered
# ...

# %%
df.onsetEstimate.first_valid_index()

# %%
df.drop('onsetEstimate', axis=1, inplace=True)

# %%
df
# Out:
#       patientId  reportedOn ageEstimate gender                      city  \
# 0             1  30/01/2020          20      F                  Thrissur
# 3             4  02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             5  02/03/2020          24      M                 Hyderabad
# 5             6  03/03/2020          69      M                    Jaipur
# 6             7  04/03/2020          55    NaN                  Gurugram
# ...         ...         ...         ...    ...                       ...
# 5094       5095  07/04/2020          27      M                       NaN
# 5095       5096  07/04/2020          67      F                       NaN
# 5096       5097  07/04/2020          40      M                       NaN
# 5097       5098  07/04/2020          42      F                       NaN
# 5098       5099  07/04/2020          40      M                       NaN
#
#         district      state        status  \
# 0       Thrissur     Kerala     Recovered
# ...

# %%
df.dropna(subset=['gender'], axis=0, inplace=True)

# %%
df
# Out:
#       patientId  reportedOn ageEstimate gender                      city  \
# 0             1  30/01/2020          20      F                  Thrissur
# 3             4  02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             5  02/03/2020          24      M                 Hyderabad
# 5             6  03/03/2020          69      M                    Jaipur
# 20           21  04/03/2020          70      F                    Jaipur
# ...         ...         ...         ...    ...                       ...
# 5094       5095  07/04/2020          27      M                       NaN
# 5095       5096  07/04/2020          67      F                       NaN
# 5096       5097  07/04/2020          40      M                       NaN
# 5097       5098  07/04/2020          42      F                       NaN
# 5098       5099  07/04/2020          40      M                       NaN
#
#         district      state        status  \
# 0       Thrissur     Kerala     Recovered
# ...

# %%
df['reportedOn']=pd.to_datetime(df['reportedOn'])

# %%
df
# Out:
#       patientId reportedOn ageEstimate gender                      city  \
# 0             1 2020-01-30          20      F                  Thrissur
# 3             4 2020-02-03          45      M  East Delhi (Mayur Vihar)
# 4             5 2020-02-03          24      M                 Hyderabad
# 5             6 2020-03-03          69      M                    Jaipur
# 20           21 2020-04-03          70      F                    Jaipur
# ...         ...        ...         ...    ...                       ...
# 5094       5095 2020-07-04          27      M                       NaN
# 5095       5096 2020-07-04          67      F                       NaN
# 5096       5097 2020-07-04          40      M                       NaN
# 5097       5098 2020-07-04          42      F                       NaN
# 5098       5099 2020-07-04          40      M                       NaN
#
#         district      state        status  \
# 0       Thrissur     Kerala     Recovered
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 5098
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patientId           932 non-null    int64
#  1   reportedOn          932 non-null    datetime64[ns]
#  2   ageEstimate         932 non-null    object
#  3   gender              932 non-null    object
#  4   city                498 non-null    object
#  5   district            927 non-null    object
#  6   state               932 non-null    object
#  7   status              932 non-null    object
#  8   notes               911 non-null    object
#  9   contractedFrom      367 non-null    object
#  10  source1             923 non-null    object
#  11  source2             451 non-null    object
#  12  source3             91 non-null     object
#  13  nationality         549 non-null    object
#  14  backupnotes         180 non-null    object
# ...

# %%
df['gender']=pd.get_dummies(df.gender)

# %%
df
# Out:
#       patientId reportedOn ageEstimate  gender                      city  \
# 0             1 2020-01-30          20       1                  Thrissur
# 3             4 2020-02-03          45       0  East Delhi (Mayur Vihar)
# 4             5 2020-02-03          24       0                 Hyderabad
# 5             6 2020-03-03          69       0                    Jaipur
# 20           21 2020-04-03          70       1                    Jaipur
# ...         ...        ...         ...     ...                       ...
# 5094       5095 2020-07-04          27       0                       NaN
# 5095       5096 2020-07-04          67       1                       NaN
# 5096       5097 2020-07-04          40       0                       NaN
# 5097       5098 2020-07-04          42       1                       NaN
# 5098       5099 2020-07-04          40       0                       NaN
#
#         district      state        status  \
# 0       Thrissur     Kerala     Recovered
# ...

# %%
sorted_val= df.sort_values(by=['state','district'], inplace= True)

# %%
df
# Out:
#       patientId reportedOn ageEstimate  gender          city  \
# 735         736 2020-03-27          53       0           NaN
# 1400       1401 2020-03-31          10       0      Lepakshi
# 1401       1402 2020-03-31          34       1      Lepakshi
# 559         560 2020-03-24          25       0  Srikalahasti
# 1669       1670 2020-01-04          54       0           NaN
# ...         ...        ...         ...     ...           ...
# 865         866 2020-03-27           6       1           NaN
# 866         867 2020-03-27           1       1           NaN
# 258         259 2020-03-21          23       1         Habra
# 1103       1104 2020-03-29          66       0           NaN
# 1440       1441 2020-03-31          57       0           NaN
#
#                       district                        state        status  \
# 735   North and Middle Andaman  Andaman and Nicobar Islands  Hospitalized
# 1400                 Anantapur               Andhra Pradesh  Hospitalized
# ...

# %%
plt.scatter(df.status,df.reportedOn)
plt.title('Age vs Status')
plt.show()

# %%
df.patientId= np.arange(1,933,1)

# %%
df.drop(['source1','source2','source3'], axis=1, inplace= True)

# %%
plt.bar(df.index, df.status)
# Out:
# <BarContainer object of 932 artists>

# %%
print('0 Represents People from India')
print('1 Represents People from Foreign Land')
df['nationality']=pd.get_dummies(df.nationality)
# Out:
# 0 Represents People from India
# 1 Represents People from Foreign Land

# %%
sns.boxplot(df.nationality,df.index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nationality', ylabel='patientId'>

# %%
df
# Out:
#           reportedOn ageEstimate  gender          city  \
# patientId
# 1         2020-03-27          53       0           NaN
# 2         2020-03-31          10       0      Lepakshi
# 3         2020-03-31          34       1      Lepakshi
# 4         2020-03-24          25       0  Srikalahasti
# 5         2020-01-04          54       0           NaN
# ...              ...         ...     ...           ...
# 928       2020-03-27           6       1           NaN
# 929       2020-03-27           1       1           NaN
# 930       2020-03-21          23       1         Habra
# 931       2020-03-29          66       0           NaN
# 932       2020-03-31          57       0           NaN
#
#                            district                        state  \
# patientId
# 1          North and Middle Andaman  Andaman and Nicobar Islands
# 2                         Anantapur               Andhra Pradesh
# 3                         Anantapur               Andhra Pradesh
# ...
